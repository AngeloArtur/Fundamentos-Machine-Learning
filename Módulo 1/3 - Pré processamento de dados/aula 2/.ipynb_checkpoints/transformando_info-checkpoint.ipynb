# %%
import pandas as pd

# %%
titanic = pd.read_csv('../../data/titanic.csv', delimiter=";")

# %%
titanic[['female', 'male']] = pd.get_dummies(titanic.sex)

# %%
titanic = titanic.drop(['sex'], axis =1)

# %%
titanic
# Out:
#      survived  pclass   age  sibsp  parch   fare embarked   class    who  \
# 0           0       3  22.0      1      0   7.25        S   Third    man
# 1           1       1  38.0      1      0  71.28        C   First  woman
# 2           1       3  26.0      0      0   7.93        S   Third  woman
# 3           1       1  35.0      1      0  53.10        S   First  woman
# 4           0       3  35.0      0      0   8.05        S   Third    man
# ..        ...     ...   ...    ...    ...    ...      ...     ...    ...
# 886         0       2  27.0      0      0  13.00        S  Second    man
# 887         1       1  19.0      0      0  30.00        S   First  woman
# 888         0       3   NaN      1      2  23.45        S   Third  woman
# 889         1       1  26.0      0      0  30.00        C   First    man
# 890         0       3  32.0      0      0   7.75        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  female   male
# 0          True  NaN  Southampton    no  False   False   True
# 1         False    C    Cherbourg   yes  False    True  False
# 2         False  NaN  Southampton   yes   True    True  False
# 3         False    C  Southampton   yes  False    True  False
# 4          True  NaN  Southampton    no   True   False   True
# ..          ...  ...          ...   ...    ...     ...    ...
# 886        True  NaN  Southampton    no   True   False   True
# 887       False    B  Southampton   yes   True    True  False
# 888       False  NaN  Southampton    no  False    True  False
# 889        True    C    Cherbourg   yes   True   False   True
# 890        True  NaN   Queenstown    no   True   False   True
#
# [891 rows x 16 columns]

# %%
titanic.drop(['who', 'alive'], axis=1, inplace=True)

# %%
titanic
# Out:
#      survived  pclass   age  sibsp  parch   fare embarked   class  adult_male  \
# 0           0       3  22.0      1      0   7.25        S   Third        True
# 1           1       1  38.0      1      0  71.28        C   First       False
# 2           1       3  26.0      0      0   7.93        S   Third       False
# 3           1       1  35.0      1      0  53.10        S   First       False
# 4           0       3  35.0      0      0   8.05        S   Third        True
# ..        ...     ...   ...    ...    ...    ...      ...     ...         ...
# 886         0       2  27.0      0      0  13.00        S  Second        True
# 887         1       1  19.0      0      0  30.00        S   First       False
# 888         0       3   NaN      1      2  23.45        S   Third       False
# 889         1       1  26.0      0      0  30.00        C   First        True
# 890         0       3  32.0      0      0   7.75        Q   Third        True
#
#     deck  embark_town  alone  female   male
# 0    NaN  Southampton  False   False   True
# 1      C    Cherbourg  False    True  False
# 2    NaN  Southampton   True    True  False
# 3      C  Southampton  False    True  False
# 4    NaN  Southampton   True   False   True
# ..   ...          ...    ...     ...    ...
# 886  NaN  Southampton   True   False   True
# 887    B  Southampton   True    True  False
# 888  NaN  Southampton  False    True  False
# 889    C    Cherbourg   True   False   True
# 890  NaN   Queenstown   True   False   True
#
# [891 rows x 14 columns]
